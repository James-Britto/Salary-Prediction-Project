# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df.shape
# Out:
# (6704, 6)

# %%
df.duplicated().sum()
# Out:
# 4912

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# %%
df.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.rename({'Education Level':'Education_Level','Job Title':'Job_Title','Years of Experience':'Years_of_Experience'},axis=1,inplace=True)

# %%
df.Education_Level.unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
df.Education_Level.replace({"Bachelor's":"Bachelor","Bachelor's Degree":"Bachelor","Master's":"Masters","Master's Degree":"Masters","phD":"PhD","Master":"Masters"},inplace=True)

# %%
df.head()
# Out:
#     Age  Gender Education_Level          Job_Title  Years_of_Experience  \
# 0  32.0    Male        Bachelor  Software Engineer                  5.0
# 1  28.0  Female         Masters       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female        Bachelor    Sales Associate                  7.0
# 4  52.0    Male         Masters           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.Education_Level.unique()
# Out:
# array(['Bachelor', 'Masters', 'PhD', 'High School'], dtype=object)

# %%
import plotly.express as px
px.box(df,y='Age')
# Out:
# <div>                            <div id="7a99156a-6f96-408b-9bc1-fec90071bc1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a99156a-6f96-408b-9bc1-fec90071bc1d")) {                    Plotly.newPlot(                        "7a99156a-6f96-408b-9bc1-fec90071bc1d",                        [{"alignmentgroup":"True","hovertemplate":"Age=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[32.0,28.0,45.0,36.0,52.0,29.0,42.0,31.0,26.0,38.0,29.0,48.0,35.0,40.0,27.0,44.0,33.0,39.0,25.0,51.0,34.0,47.0,30.0,36.0,41.0,28.0,37.0,24.0,43.0,33.0,50.0,31.0,29.0,39.0,46.0,27.0,35.0,42.0,26.0,49.0,34.0,48.0,30.0,36.0,41.0,28.0,32.0,45.0,38.0,25.0,51.0,33.0,40.0,47.0,29.0,36.0,27.0,43.0,30.0,35.0,51.0,29.0,40.0,47.0,26.0,38.0,46.0,31.0,34.0,49.0,33.0,39.0,45.0,28.0,42.0,37.0,50.0,32.0,48.0,30.0,36.0,41.0,25.0,52.0,29.0,34.0,27.0,40.0,46.0,31.0,36.0,29.0,43.0,52.0,33.0,39.0,47.0,26.0,38.0,45.0,31.0,35.0,49.0,33.0,39.0,44.0,30.0,36.0,41.0,28.0,42.0,37.0,50.0,32.0,23.0,31.0,40.0,48.0,29.0,35.0,42.0,53.0,33.0,38.0,44.0,26.0,37.0,45.0,32.0,34.0,50.0,29.0,40.0,47.0,27.0,39.0,46.0,30.0,36.0,43.0,28.0,41.0,33.0,47.0,25.0,34.0,42.0,31.0,38.0,45.0,29.0,36.0,43.0,26.0,37.0,44.0,32.0,33.0,51.0,28.0,39.0,48.0,30.0,35.0,41.0,27.0,40.0,46.0,31.0,34.0,50.0,29.0,43.0,26.0,35.0,42.0,31.0,38.0,46.0,29.0,37.0,44.0,27.0,36.0,43.0,33.0,34.0,50.0,28.0,39.0,47.0,30.0,34.0,40.0,28.0,41.0,45.0,32.0,35.0,49.0,30.0,44.0,27.0,36.0,41.0,31.0,39.0,47.0,30.0,38.0,45.0,28.0,35.0,44.0,34.0,35.0,50.0,29.0,40.0,48.0,31.0,33.0,42.0,28.0,40.0,46.0,33.0,37.0,51.0,30.0,43.0,27.0,35.0,42.0,32.0,37.0,45.0,33.0,39.0,44.0,29.0,38.0,46.0,34.0,36.0,49.0,31.0,41.0,47.0,30.0,38.0,45.0,28.0,35.0,44.0,34.0,35.0,50.0,29.0,37.0,46.0,31.0,42.0,29.0,36.0,44.0,33.0,39.0,45.0,32.0,37.0,47.0,30.0,38.0,46.0,34.0,36.0,49.0,31.0,41.0,47.0,29.0,35.0,44.0,33.0,35.0,44.0,32.0,38.0,49.0,29.0,35.0,45.0,33.0,40.0,44.0,30.0,37.0,48.0,31.0,38.0,45.0,33.0,36.0,49.0,31.0,42.0,47.0,29.0,35.0,44.0,33.0,35.0,44.0,34.0,36.0,30.0,37.0,45.0,32.0,39.0,47.0,29.0,36.0,43.0,32.0,38.0,48.0,31.0,40.0,45.0,33.0,36.0,47.0,29.0,34.0,44.0,33.0,35.0,43.0,31.0,41.0,44.0,33.0,35.0,45.0,28.0,36.0,44.0,31.0,38.0,48.0,31.0,40.0,45.0,33.0,36.0,47.0,29.0,34.0,44.0,33.0,35.0,43.0,31.0,41.0,44.0,33.0,35.0,43.0,29.0,34.0,44.0,31.0,28.0,26.0,27.0,30.0,29.0,32.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,28.0,26.0,27.0,30.0,29.0,32.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,28.0,26.0,27.0,30.0,29.0,32.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,28.0,26.0,27.0,30.0,29.0,32.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,28.0,26.0,27.0,30.0,29.0,32.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,25.0,33.0,31.0,28.0,30.0,27.0,29.0,34.0,26.0,29.0,32.0,27.0,24.0,31.0,28.0,33.0,25.0,30.0,27.0,34.0,23.0,32.0,29.0,30.0,26.0,31.0,28.0,33.0,24.0,30.0,27.0,34.0,25.0,29.0,32.0,27.0,31.0,28.0,33.0,26.0,30.0,27.0,34.0,25.0,32.0,29.0,30.0,33.0,24.0,31.0,28.0,27.0,26.0,29.0,32.0,33.0,25.0,30.0,27.0,34.0,31.0,28.0,26.0,29.0,32.0,33.0,24.0,27.0,25.0,30.0,31.0,28.0,26.0,29.0,32.0,33.0,24.0,27.0,25.0,30.0,31.0,28.0,26.0,29.0,32.0,33.0,24.0,27.0,25.0,30.0,31.0,28.0,26.0,29.0,32.0,33.0,24.0,27.0,25.0,28.0,30.0,27.0,24.0,31.0,28.0,33.0,26.0,30.0,27.0,34.0,23.0,32.0,29.0,30.0,26.0,31.0,28.0,33.0,24.0,30.0,27.0,34.0,25.0,29.0,32.0,27.0,31.0,28.0,33.0,26.0,30.0,27.0,34.0,25.0,32.0,29.0,30.0,33.0,24.0,31.0,28.0,27.0,26.0,29.0,32.0,33.0,25.0,30.0,27.0,34.0,31.0,28.0,26.0,29.0, ...

# %%
df['Age']=np.clip(df['Age'],21,53)

# %%
df.head()
# Out:
#     Age  Gender Education_Level          Job_Title  Years_of_Experience  \
# 0  32.0    Male        Bachelor  Software Engineer                  5.0
# 1  28.0  Female         Masters       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female        Bachelor    Sales Associate                  7.0
# 4  52.0    Male         Masters           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
pd.options.display.max_rows=200

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from category_encoders import BinaryEncoder

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection import train_test_split

# %%
X=df.drop('Salary',axis=1)
y=df['Salary']
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
num_cols=['Age','Years_of_Experience']
cat_cols=['Gender','Job_Title']
ord_cols=['Education_Level']

num_pipe=Pipeline(steps=[('standard',StandardScaler())],)
ord_pipe=Pipeline(steps=[('ordinal',OrdinalEncoder(categories=[['High School','Bachelor', 'Masters', 'PhD']]))],)
cat_pipe=Pipeline(steps=[('cat',BinaryEncoder(cols=cat_cols))],)

preprocessor=ColumnTransformer(transformers=[('numeric',num_pipe,num_cols),('ordin',ord_pipe,ord_cols),('categ',cat_pipe,cat_cols)],remainder='passthrough')

# %%
X_train=preprocessor.fit_transform(X_train)
X_test=preprocessor.transform(X_test)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
Y_test
# Out:
# 1883    150000.0
# 2630     75969.0
# 498     100000.0
# 5973     60000.0
# 4108     80000.0
#           ...
# 5021    120000.0
# 2592    185462.0
# 5706     70000.0
# 2929    150729.0
# 499     190000.0
# Name: Salary, Length: 1675, dtype: float64

# %%
model.score(X_test,Y_test)
# Out:
# 0.716698338901687

# %%
ls=Lasso(alpha=100,max_iter=1000)
ls.fit(X_train,Y_train)
# Out:
# Lasso(alpha=100)

# %%
ls.score(X_test,Y_test)
# Out:
# 0.7175153008212871

# %%
ls_pred=ls.predict(X_test)

# %%
rg=Ridge(alpha=100,max_iter=1000)
rg.fit(X_train,Y_train)
# Out:
# Ridge(alpha=100, max_iter=1000)

# %%
rg.score(X_test,Y_test)
# Out:
# 0.7161934235844925

# %%
rg_pred=rg.predict(X_test)

# %%
import joblib
joblib.dump(ls,'salary_prediction.pickle')
# Out:
# ['salary_prediction.pickle']

# %%
joblib.dump(preprocessor,'model_transformer.pickle')
# Out:
# ['model_transformer.pickle']

# %%
X_test.iloc[0].to_frame('0').T
# Out:
#     Age Gender Education_Level           Job_Title Years_of_Experience
# 0  36.0   Male         Masters  Back end Developer                 9.0

# %%
processor=joblib.load(open('model_transformer.pickle','rb'))
processor.transform(X_test.iloc[0].to_frame('0').T)
# Out:
# array([[0.32533386, 0.15297122, 2.        , 0.        , 1.        ,
#         0.        , 0.        , 0.        , 1.        , 0.        ,
#         1.        , 0.        , 0.        ]])

# %%
Age = 25
Gender= "Male"
Education_Level= "Bachelor"
Job_Title= "Data Analyst"
Years_of_experience= 3
frame=pd.DataFrame({'Age':[Age],'Years_of_Experience':[Years_of_experience],'Education_Level':[Education_Level],'Gender':[Gender],'Job_Title':[Job_Title]})

# %%
processor.transform(frame)
# Out:
# array([[-1.14759894, -0.84784211,  1.        ,  0.        ,  1.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          1.        ,  1.        ,  1.        ]])
